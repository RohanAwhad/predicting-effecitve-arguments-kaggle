# %%
import pandas as pd

df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#    discourse_id      essay_id  \
# 0  0013cc385424  007ACE74B050
# 1  9704a709b505  007ACE74B050
# 2  c22adee811b6  007ACE74B050
# 3  a10d361e54e4  007ACE74B050
# 4  db3e453ec4e2  007ACE74B050
#
#                                       discourse_text discourse_type  \
# 0  Hi, i'm Isaac, i'm going to be writing about h...           Lead
# 1  On my perspective, I think that the face is a ...       Position
# 2  I think that the face is a natural landform be...          Claim
# 3  If life was on Mars, we would know by now. The...       Evidence
# 4  People thought that the face was formed by ali...   Counterclaim
#
#   discourse_effectiveness
# 0                Adequate
# 1                Adequate
# 2                Adequate
# 3                Adequate
# 4                Adequate

# %%
display(df.iloc[0, 2])
# Out:
# "Hi, i'm Isaac, i'm going to be writing about how this face on Mars is a natural landform or if there is life on Mars that made it. The story is about how NASA took a picture of Mars and a face was seen on the planet. NASA doesn't know if the landform was created by life on Mars, or if it is just a natural landform. "

# %%
df.sample(10)
# Out:
#        discourse_id      essay_id  \
# 15359  e828207173c1  0CA9AC7879C9
# 16000  43568970fe23  15F80BF4B3C9
# 3391   fc35886ff045  3D3E4F0B74D2
# 16762  536e94ee7f03  21A162D4B0CB
# 5311   3ebedeb0e4f6  6120EF6FC0BF
# 11225  64f03b4e19bb  C9AC065BB597
# 3519   ff34c4a3f81a  3F142A739C54
# 34516  354222fad153  5C69070E1E48
# 5686   fa761541f68c  67D58F9FA53C
# 12713  1d171d53a13c  E595E218D423
#
#                                           discourse_text discourse_type  \
# 15359  Reasons why is because the electorial college ...       Evidence
# 16000  this method is also less complicated, leaving ...          Claim
# 3391   It is not suprising that the temperature avera...       Evidence
# 16762  The Electoral College does not give a single v...          Claim
# 5311   However, in high school, it is better to give ...   Counterclaim
# 11225  Do you belive in weird landforms?\n\nI believe...           Lead
# 3519   It's something positive for students to do dur...          Claim
# 34516  Students would benefit from being able to atte...          Claim
# 5686   I also disagree because some students need to ...   Counterclaim
# 12713     Just imagine how good of a idea this would be        Position
#
#       discourse_effectiveness
# 15359                Adequate
# 16000               Effective
# 3391                 Adequate
# 16762               Effective
# 5311                Effective
# 11225                Adequate
# 3519                 Adequate
# 34516                Adequate
# 5686                 Adequate
# 12713                Adequate

# %%
display(df.loc[22709, 'discourse_text'])
# Out:
# "It is not a complicated system that people don't understand and works well with our country. Electoral College should stay, many would argue it is not a democratic modern sense but this country is a democracy so of course the system of which we pick our president has to be democratic. "

# %%
display(df.loc[7685, 'discourse_text'])
# Out:
# 'The majority of Americans have the luxury of owning a car. A car of course, seems like a useful innovation. It gets you places quickly and efficently, and is easier than walking. Yet so many people drive cars that the roads get congested and clogged easily as the cars just idle in the road waiting for the traffic jam to loosen up. Car usage causes the enviroment to decline and an increase in air poulltion, '

# %%
df[df['essay_id'] == '8B696D4A84A0']
# Out:
#       discourse_id      essay_id  \
# 7685  148fe218d6a7  8B696D4A84A0
# 7686  c8b39930d9de  8B696D4A84A0
# 7687  150912597748  8B696D4A84A0
# 7688  4a83e5d52d55  8B696D4A84A0
# 7689  188bd2dca358  8B696D4A84A0
# 7690  6d05034fdf90  8B696D4A84A0
# 7691  faf39d9cf27f  8B696D4A84A0
# 7692  872e8bde3bf3  8B696D4A84A0
# 7693  d9d7c7c0ee16  8B696D4A84A0
# 7694  732f39a42bf7  8B696D4A84A0
# 7695  84b1272e7aaf  8B696D4A84A0
# 7696  44827ca7d413  8B696D4A84A0
# 7697  473a87f45518  8B696D4A84A0
#
#                                          discourse_text        discourse_type  \
# 7685  The majority of Americans have the luxury of o...                  Lead
# 7686  it would be a great idea to lower car usage si...              Position
# 7687  An advantage to reducing car usage is a more b...                 Claim
# 7688  "Passenger cars are responsible for 12 percent...              Evidence
# 7689  Cars also cause poulltion and smog to hang ove...              Evidence
# 7690  With less car usage smog and pollution would d...                 Claim
# 7691  Driving not only creates an issue with air pol...                 Claim
# 7692  Cars run on gasoline, a fossil fuel. Which is ...              Evidence
# 7693  Many people agree with the statment  that with...              Evidence
# 7694  Another advantage to reducing car usage is les...                 Claim
# 7695  Also to some people a car is just a backup for...              Evidence
# 7696  By improving public transport we reduce car us...                 Claim
# 7697  Less car usage will help the enviroment as wel...  Concluding Statement
#
#      discourse_effectiveness
# 7685               Effective
# 7686               Effective
# 7687               Effective
# 7688                Adequate
# 7689               Effective
# 7690                Adequate
# 7691               Effective
# 7692                Adequate
# 7693               Effective
# 7694                Adequate
# 7695                Adequate
# 7696               Effective
# 7697               Effective

# %% [markdown]
# Using the discourse type is necessary. It influences how the discourse needs to be viewed. And in turn judged. This could mean we have to consider, a causal type of architecture. That means, based on the type the scores should also change. For this I should refer to the causal paper which had 4 learning objectives, 1 different, other 3 were the same.
#
# Also, try distilling the model. That is one of the key things. If we can distill it which will make it faster, then we can increase our ranking in the effectiveness ranking too!

# %%
import codecs
import os

from text_unidecode import unidecode
from typing import Tuple

# %%
COMP_DIR = '../data/'

# %%
def replace_encoding_with_utf8(error: UnicodeError) -> Tuple[bytes, int]:
    return error.object[error.start : error.end].encode("utf-8"), error.end


def replace_decoding_with_cp1252(error: UnicodeError) -> Tuple[str, int]:
    return error.object[error.start : error.end].decode("cp1252"), error.end

codecs.register_error("replace_encoding_with_utf8", replace_encoding_with_utf8)
codecs.register_error("replace_decoding_with_cp1252", replace_decoding_with_cp1252)


def resolve_encodings_and_normalize(text: str) -> str:
    text = (
        text.encode("raw_unicode_escape")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
        .encode("cp1252", errors="replace_encoding_with_utf8")
        .decode("utf-8", errors="replace_decoding_with_cp1252")
    )
    
    text = unidecode(text)
    
    return text


def fetch_essay(essay_id: str, txt_dir: str):
    essay_path = os.path.join(COMP_DIR + txt_dir, essay_id + '.txt')
    essay_text = open(essay_path, 'r').read()
    
    return essay_text


def prepare_input(cfg, text, text_2=None):
    inputs = cfg.tokenizer(text, text_2,
                           padding="max_length",
                           add_special_tokens=True,
                           max_length=cfg.max_len,
                           truncation=True)

    for k, v in inputs.items():
        inputs[k] = torch.tensor(v, dtype=torch.long)
        
    return inputs


def inference_fn(test_loader, model, device):
    preds = []
    model.eval()
    model.to(device)
    tk0 = tqdm(test_loader, total=len(test_loader))
    
    for inputs in tk0:
        for k, v in inputs.items():
            inputs[k] = v.to(device)
            
        with torch.no_grad():
            output = model(inputs)
        
        preds.append(F.softmax(output).to('cpu').numpy())

    return np.concatenate(preds)  


def show_gradient(df, n_row=None):
    if not n_row:
        n_row = 5

    return df.head(n_row) \
                .assign(all_mean=lambda x: x.mean(axis=1)) \
                    .style.background_gradient(cmap=cm, axis=1)

# %%
df['discourse_text_UPD'] = df['discourse_text'].apply(resolve_encodings_and_normalize)

df['essay_text'] = df['essay_id'].transform(fetch_essay, txt_dir='train')
df['essay_text_UPD'] = df['essay_text'].apply(resolve_encodings_and_normalize)

df['discourse_text_UPD'] = df['discourse_text_UPD'].apply(lambda x: x.strip())
df['essay_text_UPD'] = df['essay_text_UPD'].apply(lambda x: x.strip())

df.sample(5)
# Out:
#        discourse_id      essay_id  \
# 2761   7a42f20f7a13  31F4831C794D
# 5795   443d67140ccc  6A273D6F0816
# 26552  0358ebd2f2f2  A47BE7BB6F08
# 1577   90c9df281113  1DEDB886B240
# 14667  15c9fe0f67d1  04DEFB0B11C5
#
#                                           discourse_text  \
# 2761   some people might say that is not true and if ...
# 5795   Overall, both students and teachers benefit wh...
# 26552  The Electoral college is a proccess that was e...
# 1577   The new technology called the Facial Action Co...
# 14667  Under the electoral collage system, voters vot...
#
#              discourse_type discourse_effectiveness  \
# 2761           Counterclaim               Effective
# 5795   Concluding Statement               Effective
# 26552              Evidence             Ineffective
# 1577               Position                Adequate
# 14667              Evidence             Ineffective
#
#                                       discourse_text_UPD  \
# 2761   some people might say that is not true and if ...
# 5795   Overall, both students and teachers benefit wh...
# 26552  The Electoral college is a proccess that was e...
# 1577   The new technology called the Facial Action Co...
# 14667  Under the electoral collage system, voters vot...
#
#                                               essay_text  \
# 2761   Student-designed summer projects would be more...
# 5795   It's the last day of school, and students are ...
# 26552  The Electoral college is a proccess that was e...
# 1577   The new technology called the Facial Action Co...
# 14667  The united states has this ellection system ca...
#
#                                           essay_text_UPD
# 2761   Student-designed summer projects would be more...
# 5795   It's the last day of school, and students are ...
# 26552  The Electoral college is a proccess that was e...
# 1577   The new technology called the Facial Action Co...
# 14667  The united states has this ellection system ca...

# %%
def print_before_and_after_UPD(indx, df):
    data = df.loc[indx]
    disc_text = data.discourse_text
    disc_text_upd = data.discourse_text_UPD

    print(f'\nindex: {indx} ===')
    print(f'\n>>> origin text:')
    print(repr(disc_text))
    print(f'\n>>> updated text:')
    print(repr(disc_text_upd))

# %%
print_before_and_after_UPD(49, df)
# Out:
# index: 49 ===
#
# >>> origin text:
# "Often times throughout middle school, my teachers would give the students each other's assignments to grade themselves. And afterwards, we would see in the grade book\xa0that the grade changed because the students weren't grading the assignments the way they should have been. The student grading was meant to engage the classroom, but it turned into a showcase of how students dont really know how to grade the way teachers do. If students are unaware of how a project is supposed to be graded, they can not successfully design a project that tests whether or not they understand the material. "
#
# >>> updated text:
# "Often times throughout middle school, my teachers would give the students each other's assignments to grade themselves. And afterwards, we would see in the grade book that the grade changed because the students weren't grading the assignments the way they should have been. The student grading was meant to engage the classroom, but it turned into a showcase of how students dont really know how to grade the way teachers do. If students are unaware of how a project is supposed to be graded, they can not successfully design a project that tests whether or not they understand the material."

# %%
print_before_and_after_UPD(80, df)
# Out:
# index: 80 ===
#
# >>> origin text:
# 'President Obama has done nothing to improve our society.\xa0 If anything, he has created the worst society this world has ever seen. \n'
#
# >>> updated text:
# 'President Obama has done nothing to improve our society.  If anything, he has created the worst society this world has ever seen.'

# %%
print_before_and_after_UPD(945, df)
# Out:
# index: 945 ===
#
# >>> origin text:
# 'The article says, ¨... humans have sent numerous spacecraft to land on this cloud-draped world,¨ and then says ¨... since no spacecraft survived the landing for more than a few hours.¨ If a spacecraft made by people can not survive the landing on Venus numerous times, how can we even come close to surviving the trip? Venus is too dangerous to explore and it is a waste to even send a spacecraft. The spacecrafts cost a good amount of money to make and for them to be wasted on a inhospitable planet is not worth the information we would achieve. \n'
#
# >>> updated text:
# 'The article says, "... humans have sent numerous spacecraft to land on this cloud-draped world," and then says "... since no spacecraft survived the landing for more than a few hours." If a spacecraft made by people can not survive the landing on Venus numerous times, how can we even come close to surviving the trip? Venus is too dangerous to explore and it is a waste to even send a spacecraft. The spacecrafts cost a good amount of money to make and for them to be wasted on a inhospitable planet is not worth the information we would achieve.'

# %%
id2label = {
    0: 'Ineffective',
    1: 'Adequate',
    2: 'Effective',
}
label2id = dict((v, k) for k, v in id2label.items())

label2id
# Out:
# {'Ineffective': 0, 'Adequate': 1, 'Effective': 2}

# %%
df['labels'] = df['discourse_effectiveness'].apply(lambda x: label2id[x])
df.head()
# Out:
#    discourse_id      essay_id  \
# 0  0013cc385424  007ACE74B050
# 1  9704a709b505  007ACE74B050
# 2  c22adee811b6  007ACE74B050
# 3  a10d361e54e4  007ACE74B050
# 4  db3e453ec4e2  007ACE74B050
#
#                                       discourse_text discourse_type  \
# 0  Hi, i'm Isaac, i'm going to be writing about h...           Lead
# 1  On my perspective, I think that the face is a ...       Position
# 2  I think that the face is a natural landform be...          Claim
# 3  If life was on Mars, we would know by now. The...       Evidence
# 4  People thought that the face was formed by ali...   Counterclaim
#
#   discourse_effectiveness                                 discourse_text_UPD  \
# 0                Adequate  Hi, i'm Isaac, i'm going to be writing about h...
# 1                Adequate  On my perspective, I think that the face is a ...
# 2                Adequate  I think that the face is a natural landform be...
# 3                Adequate  If life was on Mars, we would know by now. The...
# 4                Adequate  People thought that the face was formed by ali...
#
#                                           essay_text  \
# 0  Hi, i'm Isaac, i'm going to be writing about h...
# 1  Hi, i'm Isaac, i'm going to be writing about h...
# 2  Hi, i'm Isaac, i'm going to be writing about h...
# 3  Hi, i'm Isaac, i'm going to be writing about h...
# 4  Hi, i'm Isaac, i'm going to be writing about h...
#
#                                       essay_text_UPD  labels
# 0  Hi, i'm Isaac, i'm going to be writing about h...       1
# 1  Hi, i'm Isaac, i'm going to be writing about h...       1
# 2  Hi, i'm Isaac, i'm going to be writing about h...       1
# 3  Hi, i'm Isaac, i'm going to be writing about h...       1
# 4  Hi, i'm Isaac, i'm going to be writing about h...       1

# %%
shuffled_df = df.sample(frac=1)

# %%
shuffled_df[:2000].to_parquet(COMP_DIR+'test_UPD.parquet')
shuffled_df[2000:].to_parquet(COMP_DIR+'train_UPD.parquet')

# %%
sample_df = df.sample(100)

sample_df[:20]
# Out:
#        discourse_id      essay_id  \
# 18724  34231c29f74a  39F8DB13BB4F
# 26022  48eae7707264  9DF8A166D993
# 5739   2ea574c21e6b  68D87C1576F3
# 4402   74d6929d41c4  4E2B21AF8C1D
# 31283  3aa15cc835f0  E74E4865B395
# 13015  b5c9fcaa868a  EAF6BCA737BD
# 28207  09159e5e79d2  B7E3F460802A
# 24093  4c50cce4cf72  811DE32FCE53
# 3312   dc3f884db3d3  3BFD98581812
# 12649  679dca5b7ed3  E47590B3F2CF
# 30202  7a9890b7893b  D8F3209E84CF
# 25623  d496e838a837  971D0C1C75F0
# 4278   bd6ad6811ac5  4C30EEDA3A8F
# 6554   63c4501c72bc  77013FCECE6F
# 9374   8fc6076391ef  A969E6903C17
# 2319   f9bd1a639f25  2B23459A3938
# 8634   ae9e4e5cdaa2  9C480C68AA9B
# 10488  ec9b0f9216d5  BBEE06BD484C
# 2533   b995873f9927  2DC33D804E4A
# 15542  8bf67e3835cb  0FC4B7E09462
#
#                                           discourse_text  \
# 18724  I think that driverless cars are a bad idea be...
# 26022  not only basic people of the USA think the ele...
# 5739   In this article they talk about long ago when ...
# 4402   because sometimes people do not want show they...
# 31283  Many schools started online classes due to eme...
# 13015  The mechanical computers could be made to widt...
# 28207  First of all not only are candidates wanting t...
# 24093  Conclusively, the Electoral College is not the...
# 3312   this is however a bad way to get there for the...
# 12649  You also have a lot of free time on the way ba...
# 30202  What that piece is stating is in order to have...
# 25623  If school didn't have music, sports, etc., the...
# 4278   And there are plenty of ways to send a message...
# 6554   Being a part of the Seagoing Cowboys was a gre...
# 9374   In the article ''Unmasking the Face on Mars''\...
# 2319   The main idea of this passage is a man and Luk...
# 8634   Student designed projects will talk about thes...
# 10488  When your teacher assign a project about a top...
# 2533   In addition, beyond high pressure and hean, Ve...
# 15542  Finally,  its offical the elecoral college is ...
#
#              discourse_type discourse_effectiveness  \
# 18724  Concluding Statement                Adequate
# 26022                 Claim                Adequate
# 5739               Evidence                Adequate
# 4402                  Claim                Adequate
# 31283          Counterclaim                Adequate
# 13015              Evidence                Adequate
# 28207              Evidence             Ineffective
# 24093  Concluding Statement                Adequate
# 3312               Evidence             Ineffective
# 12649                 Claim                Adequate
# 30202                 Claim               Effective
# 25623              Evidence                Adequate
# 4278               Evidence                Adequate
# 6554               Position                Adequate
# 9374                   Lead                Adequate
# 2319               Evidence                Adequate
# 8634                  Claim                Adequate
# 10488              Evidence                Adequate
# 2533                  Claim             Ineffective
# 15542  Concluding Statement             Ineffective
#
#                                       discourse_text_UPD  \
# 18724  I think that driverless cars are a bad idea be...
# 26022  not only basic people of the USA think the ele...
# 5739   In this article they talk about long ago when ...
# 4402   because sometimes people do not want show they...
# 31283  Many schools started online classes due to eme...
# 13015  The mechanical computers could be made to widt...
# 28207  First of all not only are candidates wanting t...
# 24093  Conclusively, the Electoral College is not the...
# 3312   this is however a bad way to get there for the...
# 12649  You also have a lot of free time on the way ba...
# 30202  What that piece is stating is in order to have...
# 25623  If school didn't have music, sports, etc., the...
# 4278   And there are plenty of ways to send a message...
# 6554   Being a part of the Seagoing Cowboys was a gre...
# 9374   In the article ''Unmasking the Face on Mars''\...
# 2319   The main idea of this passage is a man and Luk...
# 8634   Student designed projects will talk about thes...
# 10488  When your teacher assign a project about a top...
# 2533   In addition, beyond high pressure and hean, Ve...
# 15542  Finally,  its offical the elecoral college is ...
#
#                                               essay_text  \
# 18724  How safe would you feel if you there was a car...
# 26022  The Electoral College\n\nDear Mr. Nixon\n\nI t...
# 5739   The author tells us a lot about Venus in the a...
# 4402   Why they invent Facial Action Coding System? W...
# 31283  Many schools throughout the world offer distan...
# 13015  In the article "The Challenge od Exploring Ven...
# 28207  Senator i argue that the state shouald change ...
# 24093  Dear State Senator,\n\nI do not like the Elect...
# 3312   in the artical the autoer shows how they would...
# 12649  You should become a Seagoing Cowboy like me, L...
# 30202  In the article "Driverless Cars Are Coming," t...
# 25623  Dear Principal,\n\nI completely disagree with ...
# 4278   There shouldn't be a discussion when it comes ...
# 6554   Being a part of the Seagoing Cowboys was a gre...
# 9374   In the article ''Unmasking the Face on Mars''\...
# 2319   Luke took a trip with a friend and he went to ...
# 8634   If the Summer is plagued with more work we sho...
# 10488  Some schools require students to complete summ...
# 2533   The auther suggedts that studying Venus is a w...
# 15542  The state senetor should keep the electoral co...
#
#                                           essay_text_UPD  labels
# 18724  How safe would you feel if you there was a car...       1
# 26022  The Electoral College\n\nDear Mr. Nixon\n\nI t...       1
# 5739   The author tells us a lot about Venus in the a...       1
# 4402   Why they invent Facial Action Coding System? W...       1
# 31283  Many schools throughout the world offer distan...       1
# 13015  In the article "The Challenge od Exploring Ven...       1
# 28207  Senator i argue that the state shouald change ...       0
# 24093  Dear State Senator,\n\nI do not like the Elect...       1
# 3312   in the artical the autoer shows how they would...       0
# 12649  You should become a Seagoing Cowboy like me, L...       1
# 30202  In the article "Driverless Cars Are Coming," t...       2
# 25623  Dear Principal,\n\nI completely disagree with ...       1
# 4278   There shouldn't be a discussion when it comes ...       1
# 6554   Being a part of the Seagoing Cowboys was a gre...       1
# 9374   In the article ''Unmasking the Face on Mars''\...       1
# 2319   Luke took a trip with a friend and he went to ...       1
# 8634   If the Summer is plagued with more work we sho...       1
# 10488  Some schools require students to complete summ...       1
# 2533   The auther suggedts that studying Venus is a w...       0
# 15542  The state senetor should keep the electoral co...       0

# %%
sample_df[:20].to_parquet('../data/sample_test.parquet')
sample_df[20:].to_parquet('../data/sample_train.parquet')
